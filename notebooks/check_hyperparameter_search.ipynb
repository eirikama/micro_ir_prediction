# %%
study = optuna.load_study(study_name="milk_augmentation_sweep", storage=storage_path)

print(f"Number of trials: {len(study.trials)}")
print(f"Best value: {study.best_value}")
print(f"Best params:")
for k, v in study.best_params.items():
    print(f"  {k}: {v}")
print(f"Best trial number: {study.best_trial.number}")
# Out:
# Number of trials: 46
# Best value: 0.656360411494459
# Best params:
#   model.lr: 4.5619219250590724e-05
#   model.weight_decay: 0.00044602386569686845
#   data.augmentations.polynomial_baseline_signal.ratio: 0.566470630971798
#   data.augmentations.polynomial_baseline_signal.p0_max: 0.25844206311979784
#   data.augmentations.polynomial_baseline_signal.p1_min: 0.27628417771946473
#   data.augmentations.polynomial_baseline_signal.p1_max: 2.5318041171769887
#   data.augmentations.polynomial_baseline_signal.p2_max: 0.000359544347742558
#   data.augmentations.noise.ratio: 0.29774536452387623
#   data.augmentations.noise.max_level: 0.0008099340355878741
#   data.augmentations.co2_peaks.enabled: False
#   data.augmentations.co2_peaks.ratio: 0.10682439793214796
#   data.augmentations.co2_peaks.d_height: 0.3845484900498149
#   data.augmentations.wavenumber_shift.enabled: True
#   data.augmentations.wavenumber_shift.ratio: 0.5863866383857042
#   data.augmentations.wavenumber_shift.shift_max: 2.4750552095736955
#   data.augmentations.homogenizer_degradation.enabled: False
#   data.augmentations.homogenizer_degradation.ratio: 0.5498430825563753
#   data.augmentations.homogenizer_degradation.amplitude_max: 0.2921394399942931
#   data.augmentations.homogenizer_degradation.bump_width: 195.75466005116922
#   data.augmentations.homogenizer_degradation.bump_center_jitter: 74.4397734441955
#   data.augmentations.temperature_perturbation.enabled: True
#   data.augmentations.temperature_perturbation.ratio: 0.5129778818700246
#   data.augmentations.temperature_perturbation.temp_delta_max: 1.8712891555618902
#   data.augmentations.temperature_perturbation.shift_per_degree: 0.4871632900881332
#   data.augmentations.preservative_effect_azidiol.enabled: False
#   data.augmentations.preservative_effect_azidiol.ratio: 0.20471547209730942
#   data.augmentations.preservative_effect_azidiol.amplitude_max: 0.0406769154733737
#   data.augmentations.preservative_effect_azidiol.shift_max: 0.19763295653203694
#   data.augmentations.preservative_effect_bronopol.enabled: False
#   data.augmentations.preservative_effect_bronopol.ratio: 0.13156111578544563
#   data.augmentations.preservative_effect_bronopol.amplitude_max: 0.04613430317896162
#   data.augmentations.preservative_effect_bronopol.shift_max: 1.8571743975362818
#   data.augmentations.dilution.enabled: False
#   data.augmentations.dilution.ratio: 0.36795113100383275
#   data.augmentations.dilution.dilution_max: 0.2221679533174747
# Best trial number: 25

# %%
df = study.trials_dataframe()
df_complete = df[df["state"] == "COMPLETE"].sort_values("value", ascending=False)
df_complete.columns = df_complete.columns.str.replace("params_data.", "", regex=False)
df_complete = df_complete.drop(columns=['datetime_start', 'datetime_complete', 'duration', 'user_attrs_domain', 'user_attrs_mode', 'state'])
df_complete.head(10)
# Out:
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:598: FutureWarning: LogUniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   return cls(**json_dict["attributes"])
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:598: FutureWarning: UniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   return cls(**json_dict["attributes"])
#     number     value  augmentations.co2_peaks.d_height  \
# 25      25  0.656360                          0.384548
# 24      24  0.646570                          0.398748
# 35      35  0.635120                          0.504139
# 44      44  0.634331                          0.351292
# 29      29  0.619744                          0.396287
# 22      22  0.618308                          0.388371
# 31      31  0.611886                          0.385462
# 26      26  0.610467                          0.393616
# 28      28  0.609843                          0.256101
# 23      23  0.609377                          0.416406
#
#     augmentations.co2_peaks.enabled  augmentations.co2_peaks.ratio  \
# 25                            False                       0.106824
# 24                            False                       0.118905
# 35                            False                       0.096346
# 44                            False                       0.151731
# 29                            False                       0.129369
# 22                            False                       0.112888
# 31                            False                       0.137456
# 26                            False                       0.097843
# 28                            False                       0.248604
# 23                            False                       0.112317
#
#     augmentations.dilution.dilution_max  augmentations.dilution.enabled  \
# 25                             0.222168                           False
# 24                             0.223365                           False
# 35                             0.147018                           False
# 44                             0.234825                           False
# 29                             0.161024                           False
# 22                             0.227341                           False
# 31                             0.129646                           False
# 26                             0.213203                           False
# 28                             0.225766                           False
# 23                             0.226671                           False
#
#     augmentations.dilution.ratio  \
# 25                      0.367951
# 24                      0.371556
# 35                      0.308159
# 44                      0.309255
# 29                      0.313761
# 22                      0.374909
# 31                      0.321549
# 26                      0.339006
# 28                      0.247777
# 23                      0.373399
#
#     augmentations.homogenizer_degradation.amplitude_max  \
# 25                                           0.292139
# 24                                           0.109276
# 35                                           0.105402
# 44                                           0.129064
# 29                                           0.075047
# 22                                           0.014156
# 31                                           0.064202
# 26                                           0.104387
# 28                                           0.047912
# 23                                           0.296917
#
#     augmentations.homogenizer_degradation.bump_center_jitter  ...  \
# 25                                          74.439773         ...
# 24                                          75.448728         ...
# 35                                          72.995519         ...
# 44                                          64.973310         ...
# 29                                          49.275540         ...
# 22                                          73.896392         ...
# 31                                          40.910562         ...
# 26                                          59.517063         ...
# 28                                          64.278134         ...
# 23                                          71.131722         ...
#
#     augmentations.preservative_effect_bronopol.shift_max  \
# 25                                           1.857174
# 24                                           1.876193
# 35                                           1.577140
# 44                                           1.995534
# 29                                           0.412099
# 22                                           1.780966
# 31                                           0.415329
# 26                                           1.995380
# 28                                           1.654572
# 23                                           1.784165
#
#     augmentations.temperature_perturbation.enabled  \
# 25                                            True
# 24                                            True
# 35                                           False
# 44                                            True
# 29                                           False
# 22                                            True
# 31                                           False
# 26                                           False
# 28                                            True
# 23                                            True
#
#     augmentations.temperature_perturbation.ratio  \
# 25                                      0.512978
# 24                                      0.528019
# 35                                      0.632967
# 44                                      0.427328
# 29                                      0.673263
# 22                                      0.554261
# 31                                      0.436838
# 26                                      0.394174
# 28                                      0.561104
# 23                                      0.530164
#
#     augmentations.temperature_perturbation.shift_per_degree  \
# 25                                           0.487163
# 24                                           0.511046
# 35                                           0.427970
# 44                                           0.410345
# 29                                           0.472233
# 22                                           0.378869
# 31                                           0.458923
# 26                                           0.527936
# 28                                           0.551349
# 23                                           0.482871
#
#     augmentations.temperature_perturbation.temp_delta_max  \
# 25                                           1.871289
# 24                                           1.896444
# 35                                           0.940362
# 44                                           0.890623
# 29                                           1.092106
# 22                                           1.957802
# 31                                           1.185462
# 26                                           1.290801
# 28                                           0.760381
# 23                                           1.859614
#
#     augmentations.wavenumber_shift.enabled  \
# 25                                    True
# 24                                    True
# 35                                    True
# 44                                    True
# 29                                    True
# 22                                    True
# 31                                    True
# 26                                   False
# 28                                    True
# 23                                    True
#
#     augmentations.wavenumber_shift.ratio  \
# 25                              0.586387
# 24                              0.557763
# 35                              0.838492
# 44                              0.775408
# 29                              0.727348
# 22                              0.799485
# 31                              0.706172
# 26                              0.644994
# 28                              0.564786
# 23                              0.564102
#
#     augmentations.wavenumber_shift.shift_max  params_model.lr  \
# 25                                  2.475055         0.000046
# 24                                  3.083038         0.000070
# 35                                  3.040574         0.000012
# 44                                  3.962278         0.000037
# 29                                  2.705629         0.000023
# 22                                  2.976380         0.000090
# 31                                  2.926288         0.000050
# 26                                  2.434126         0.000033
# 28                                  1.210998         0.000013
# 23                                  3.123637         0.000083
#
#     params_model.weight_decay
# 25                   0.000446
# 24                   0.000495
# 35                   0.000818
# 44                   0.004048
# 29                   0.000059
# 22                   0.002002
# 31                   0.000019
# 26                   0.000417
# 28                   0.000272
# 23                   0.001485
#
# [10 rows x 37 columns]

# %%
importances = optuna.importance.get_param_importances(study)
for param, score in sorted(importances.items(), key=lambda x: -x[1]):
    print(f"{param}: {score:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:598: FutureWarning: LogUniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   return cls(**json_dict["attributes"])
# /usr/local/lib/python3.12/dist-packages/optuna/distributions.py:598: FutureWarning: UniformDistribution has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :class:`~optuna.distributions.FloatDistribution` instead.
#   return cls(**json_dict["attributes"])
# data.augmentations.wavenumber_shift.shift_max: 0.179
# data.augmentations.co2_peaks.d_height: 0.137
# data.augmentations.preservative_effect_bronopol.shift_max: 0.056
# data.augmentations.noise.max_level: 0.055
# data.augmentations.preservative_effect_azidiol.amplitude_max: 0.050
# data.augmentations.preservative_effect_bronopol.ratio: 0.050
# data.augmentations.homogenizer_degradation.amplitude_max: 0.046
# data.augmentations.dilution.dilution_max: 0.040
# data.augmentations.homogenizer_degradation.bump_width: 0.031
# data.augmentations.polynomial_baseline_signal.p2_max: 0.030
# data.augmentations.noise.ratio: 0.028
# data.augmentations.dilution.ratio: 0.028
# data.augmentations.homogenizer_degradation.bump_center_jitter: 0.026
# data.augmentations.temperature_perturbation.temp_delta_max: 0.025
# data.augmentations.polynomial_baseline_signal.p1_max: 0.025
# data.augmentations.polynomial_baseline_signal.p0_max: 0.024
# model.weight_decay: 0.024
# data.augmentations.temperature_perturbation.ratio: 0.020
# data.augmentations.preservative_effect_azidiol.shift_max: 0.018
# data.augmentations.homogenizer_degradation.ratio: 0.017
# data.augmentations.preservative_effect_bronopol.amplitude_max: 0.013
# data.augmentations.wavenumber_shift.enabled: 0.013
# data.augmentations.temperature_perturbation.shift_per_degree: 0.011
# data.augmentations.wavenumber_shift.ratio: 0.011
# data.augmentations.polynomial_baseline_signal.p1_min: 0.009
# data.augmentations.preservative_effect_azidiol.ratio: 0.008
# model.lr: 0.005
# data.augmentations.homogenizer_degradation.enabled: 0.005
# data.augmentations.co2_peaks.ratio: 0.005
# data.augmentations.preservative_effect_azidiol.enabled: 0.004
# data.augmentations.polynomial_baseline_signal.ratio: 0.003
# data.augmentations.preservative_effect_bronopol.enabled: 0.002
# data.augmentations.co2_peaks.enabled: 0.001
# data.augmentations.dilution.enabled: 0.000
# data.augmentations.temperature_perturbation.enabled: 0.000
